# %% [markdown]
# # Physics 256 - Computational Physics
# ## Lecture 01 - Some Featuers

# %% [markdown]
# ### Querying python floats

# %%
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %% [markdown]
# ### Python Dynamic Typing
#
# \begin{align}
# f(N) &= \sum_{n=1}^{N} \frac{1}{n} \\
# &= \sum_{n=N}^{1} \frac{1}{n}
# \end{align}
#
# $$ f(100) = \frac{14466636279520351160221518043104131447711}{2788815009188499086581352357412492142272}
# $$

# %%
N = 100

# the exact answer for N = 100
f100 = 14466636279520351160221518043104131447711 / 2788815009188499086581352357412492142272

# initialize the sums
s1 = 0.0
s2 = 0.0

# forward sum
for n in range(1,N+1):
    s1 += 1.0/n

# backward sum
for n in range(N,0,-1):
    s2 += 1.0/n

# output results
print('f(100)  = %.16f'%f100)
print('s1      = %.16f'%s1)
print('s2      = %.16f'%s2)
print('|s1-s2| = %.2E' % (abs(s1-s2)))
# Out:
# f(100)  = 5.1873775176396206
# s1      = 5.1873775176396206
# s2      = 5.1873775176396215
# |s1-s2| = 8.88E-16

# %% [markdown]
# ### The Mandelbrot Set

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

N = 200
M = 50
mset = np.ones([N,N])

for i,x in enumerate(np.linspace(-2.0,1.0,N)):
    for j,y in enumerate(np.linspace(-1.0j,1.0j,N)):
        z0 = x+y
        z = 0
        for m in range(M):
            if abs(z) > 2:
                break
            z = z*z + z0
        mset[j,i] = 1.0/m
        

plt.imshow(mset,extent=[-2,1,-1,1],cmap='spectral')
plt.colorbar()
plt.title('The Mandelbrot Set')
plt.xlabel('Re $z_0$')
plt.ylabel('Im $z_0$')
# Out:
# <img src="data:image/png;base64,...">
